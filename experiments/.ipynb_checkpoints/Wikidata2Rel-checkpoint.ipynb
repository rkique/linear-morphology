# %% [markdown]
# This notebook queries the Wikidata API for relational knowledge, saving it in a JSON format that can be read by `dataclasses_json` as Relation objects. The focus is on symmetric relations such as `married` or `is-sibling`, but low-context relations are another area of interest that can be explored further below.

# %%
import sys
sys.path.append('..')
from lre.data import Relation, RelationSample
import json
import requests
import pandas as pd
# !ls
# Out:
# A2Rel.ipynb        RelBenchmark.py    example.json       text
# RelBenchmark.ipynb Wikidata2Rel.ipynb json               wikidata

# %%
# Define the endpoint and query
url = "https://query.wikidata.org/sparql"
query = """
SELECT ?person1 ?person1Label ?person2 ?person2Label ?marriageDate ?endDate WHERE {
  # ?person1 wdt:P26 ?person2 .
  OPTIONAL { ?person1 wdt:P580 ?marriageDate. }
  OPTIONAL { ?person1 wdt:P582 ?endDate. }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
LIMIT 100
"""

# Send the request to the Wikidata SPARQL endpoint
response = requests.get(url, params={'query': query, 'format': 'json'})
data = response.json()

# %%
data
# Out:
# {'head': {'vars': ['person1',
#    'person1Label',
#    'person2',
#    'person2Label',
#    'marriageDate',
#    'endDate']},
#  'results': {'bindings': [{'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2259'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1407'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Julia the Elder'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tiberius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57212'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1339'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Anna Magdalena Bach'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Johann Sebastian Bach'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q57487'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1339'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Maria Barbara Bach'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Johann Sebastian Bach'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q75789'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1511'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Cosima Wagner'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Richard Wagner'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q78230'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1511'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Minna Planer'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Richard Wagner'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q154732'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Agrippina the Younger'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Claudius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q210535'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Nefertari'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q215637'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1394'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Nadezhda Krupskaya'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vladimir Lenin'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q222805'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1480'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Benigno Aquino Jr.'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Corazon Aquino'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q229246'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1442'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Julia Domna'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Septimius Severus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q229871'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Messalina'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Claudius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q230716'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1413'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Poppaea Sabina'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q230716'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1416'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Poppaea Sabina'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Otho'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q231262'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1413'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Claudia Octavia'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q232090'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1407'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vipsania Agrippina'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tiberius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q232716'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1427'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vibia Sabina'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hadrian'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q233306'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1426'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mirka Federer'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Roger Federer'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q233444'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1405'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Scribonia'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Augustus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q233578'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1434'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Bruttia Crispina'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Commodus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q234734'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1429'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Faustina the Elder'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Antoninus Pius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q236259'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Plautia Urgulanilla'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Claudius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q236936'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1430'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Faustina the Younger'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Marcus Aurelius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q237618'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1405'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Claudia'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Augustus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q238151'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1446'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Fulvia Plautilla'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Caracalla'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q238448'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1411'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aelia Paetina'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Claudius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q239010'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1423'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Domitia Longina'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Domitian'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q239448'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1425'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pompeia Plotina'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Trajan'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q240928'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1409'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Milonia Caesonia'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Caligula'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q241102'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1419'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Domitilla the Elder'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vespasian'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q241445'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1413'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Statilia Messalina'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q241982'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1409'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Livia Orestilla'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Caligula'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q242199'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1409'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Junia Claudilla'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Caligula'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q242466'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1433'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lucilla'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lucius Verus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q256048'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1409'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lollia Paulina'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Caligula'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q256430'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Maathorneferure'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q256446'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Isetnofret'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q260039'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1417'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Galeria Fundana'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vitellius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q260813'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Meritamen'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q261213'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Bintanath'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q285536'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1463'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Imelda Marcos'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ferdinand Marcos'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q299633'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1526'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sitre'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses I'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q386713'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1528'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Iset Ta-Hemdjert'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses III'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q435936'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1541'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Terentia'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cicero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q443096'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1618'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Anne Morrow Lindbergh'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Charles Lindbergh'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q443473'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Henutmire'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q460946'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Nebettawy'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q469701'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1405'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Livia'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Augustus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q542643'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1417'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Petronia'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vitellius'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q731059'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1421'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Marcia Furnilla'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Titus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q739331'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1528'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tyti'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses III'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q910463'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1532'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Duatentopet'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses IV'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q969767'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1528'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tiye'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses III'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370632'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1545'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'David Thornton'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Cyndi Lauper'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1393800'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1631'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Theophanis Lamboukas'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Édith Piaf'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1528430'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1421'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Arrecina Tertulla'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Titus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1678088'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1631'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Jacques Pills'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Édith Piaf'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1965049'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1500'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Josephine Bracken'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'José Rizal'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2329627'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1413'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sporus'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2403916'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1413'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pythagoras'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2479052'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1440'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manlia Scantilla'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Didius Julianus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2604067'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1436'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Flavia Titiana'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Pertinax'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q2688967'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Arnoldas Abramavičius'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Virginia'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3066501'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1512'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Fanny Stevenson'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Robert Louis Stevenson'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3122139'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1646'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Guy Schoeller'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Françoise Sagan'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3544720'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1503'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aurora Quezon'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuel L. Quezon'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q3655890'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1414'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aemilia Lepida'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Galba'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q4794936'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1589'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Lucia Galeazzi Galvani'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Luigi Galvani'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5404530'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1330'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuela Warnes y García de Zúñiga'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'José Joaquín Prieto'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5409445'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1326'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Eulogia Echaurren'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Federico Errázuriz Zañartu'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5801729'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1324'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Delfina De la Cruz Zañartu'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Aníbal Pinto'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5834035'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1329'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Enriqueta Pinto Garmendia'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuel Bulnes'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q5984669'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1333'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Luisa Garmendia Alurralde'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Francisco Antonio Pinto'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q6112391'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1328'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Rosario Montt Goyenechea'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuel Montt'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11943302'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1541'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Publilia'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cicero'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q12653183'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Donatas Krikštaponis'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Virginia'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q12677661'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vincas Jasiukevičius'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Virginia'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q14565158'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1379'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mary Jo Powell'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gary Gygax'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q14565159'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1379'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gail Carpenter'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Gary Gygax'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16275233'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1579'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'consorts of Ganesha'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ganesha'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16449803'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Donatas Kaubrys'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Virginia'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16454030'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Julius Panka'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Virginia'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16476974'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1370'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Vytas Šimonėlis'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Virginia'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16494040'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1332'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuela Caldera Mascayano'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramón Freire'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16543577'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1331'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Carmen Gana López'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Manuel Blanco Encalada'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16643032'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1327'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Tránsito Flores de la Cavareda'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'José Joaquín Pérez'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q19776291'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1625'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ruth Randall Edström'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Sigfrid Edström'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q21179251'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1615'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Janet Shearon'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Neil Armstrong'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q22668563'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1496'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Beatriz Barbosa'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ferdinand Magellan'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q45350389'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1399'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Thomas Fontaine'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Niccolò Machiavelli'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q46371880'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1628'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Mary Montagu Douglas Scott'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'David Cecil, 6th Marquess of Exeter'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q50989199'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1442'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Paccia Marciana'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Septimius Severus'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q55762463'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1579'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ridhi'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ganesha'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q55762465'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1579'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sidhi'},
#     'person2Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ganesha'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q62927560'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1403'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Maria Antonietta Portulano'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Luigi Pirandello'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q75270813'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1628'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Diana Henderson'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'David Cecil, 6th Marquess of Exeter'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q90917344'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1615'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Carol Held Knight'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Neil Armstrong'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q103839923'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1523'},
#     'person1Label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Merytre'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Ramesses II'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q104213764'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1470'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Jetta Umiker'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'M. C. Escher'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q108668416'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1325'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Helen Berta Maria von Fritsch'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Friedrich Hayek'}},
#    {'person1': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q108668421'},
#     'person2': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q1325'},
#     'person1Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Helene Bitterlich'},
#     'person2Label': {'xml:lang': 'en',
#      'type': 'literal',
#      'value': 'Friedrich Hayek'}}]}}

# %%
relation_name = "person - spouse"
relation_path_json = "json/sym/person-spouse" + ".json"
prompts = [
    "{} is married to",
    ]
# Extract results
RelationSamples = []
for item in data['results']['bindings']:
    spouse = item['person1Label']['value']
    person = item['person2Label']['value']
    RelationSamples.append(RelationSample(person, spouse))

rel = Relation(
                name=relation_name,
                prompt_templates=prompts,
                prompt_templates_zs=prompts,
                samples=
                RelationSamples
            )

relation_json = rel.to_dict()

# %%
with open(relation_path_json, "w") as file:
    json.dump(relation_json, file, indent=4)
